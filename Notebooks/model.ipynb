# %%
import pandas as pd

transaction_path = r"E:\AI_Riskk\Data\Raw\train_transaction.csv"
identity_path = r"E:\AI_Riskk\Data\Raw\train_identity.csv"

# Read transaction data in chunks
chunks = []

for chunk in pd.read_csv(transaction_path, chunksize=50000):
    chunks.append(chunk)

db = pd.concat(chunks, ignore_index=True)

# Identity is much smaller
identity = pd.read_csv(identity_path)

print("Transaction:", db.shape)
print("Identity:", identity.shape)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 9
#       6 # Read transaction data in chunks
#       7 chunks = []
# ----> 9 for chunk in pd.read_csv(transaction_path, chunksize=50000):
#      10     chunks.append(chunk)
#      12 db = pd.concat(chunks, ignore_index=True)
#
# File e:\AI_Riskk\.venv\lib\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File e:\AI_Riskk\.venv\lib\site-packages\pandas\io\parsers\readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# ...
